# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import seaborn as sb

from tqdm import tqdm
import time
import os

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import xgboost
from sklearn.model_selection import train_test_split

import shap

# %%
X, y = shap.datasets.adult()
X_display, y_display = shap.datasets.adult(display=True)

# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)
d_train = xgboost.DMatrix(X_train, label=y_train)
d_test = xgboost.DMatrix(X_test, label=y_test)

# %%
X_display
# Out:
#         Age          Workclass  Education-Num       Marital Status  \
# 0      39.0          State-gov           13.0        Never-married
# 1      50.0   Self-emp-not-inc           13.0   Married-civ-spouse
# 2      38.0            Private            9.0             Divorced
# 3      53.0            Private            7.0   Married-civ-spouse
# 4      28.0            Private           13.0   Married-civ-spouse
# ...     ...                ...            ...                  ...
# 32556  27.0            Private           12.0   Married-civ-spouse
# 32557  40.0            Private            9.0   Married-civ-spouse
# 32558  58.0            Private            9.0              Widowed
# 32559  22.0            Private            9.0        Never-married
# 32560  52.0       Self-emp-inc            9.0   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Capital Gain  \
# 0            Adm-clerical   Not-in-family   White     Male        2174.0
# ...

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_x = X_train.values

train_x.shape
# Out:
# (26048, 12)

# %%
type(train_x)
# Out:
# numpy.ndarray

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9543/687365071.py in <cell line: 1>()
# ----> 1 train_y = y_train.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
d_train = xgboost.DMatrix(X_train.values, label=y_train)
d_test = xgboost.DMatrix(X_test.values, label=y_test)

# %%
params = {
    "eta": 0.01,
    "objective": "binary:logistic",
    "subsample": 0.5,
    "base_score": np.mean(y_train),
    "eval_metric": "logloss",
}
model = xgboost.train(
    params,
    d_train,
    5000,
    evals=[(d_test, "test")],
    verbose_eval=100,
    early_stopping_rounds=20,
)
# Out:
# [0]	test-logloss:0.54663
# [100]	test-logloss:0.36398
# [200]	test-logloss:0.31758
# [300]	test-logloss:0.30065
# [400]	test-logloss:0.29170
# [500]	test-logloss:0.28655
# [600]	test-logloss:0.28358
# [700]	test-logloss:0.28174
# [800]	test-logloss:0.28061
# [900]	test-logloss:0.27988
# [1000]	test-logloss:0.27939
# [1100]	test-logloss:0.27906
# [1178]	test-logloss:0.27887

# %%
xgboost.plot_importance(model)
plt.title("xgboost.plot_importance(model)")
plt.show()

# %%
X.head()
# Out:
#     Age  Workclass  Education-Num  Marital Status  Occupation  Relationship  \
# 0  39.0          7           13.0               4           1             0
# 1  50.0          6           13.0               2           4             4
# 2  38.0          4            9.0               0           6             0
# 3  53.0          4            7.0               2           6             4
# 4  28.0          4           13.0               2          10             5
#
#    Race  Sex  Capital Gain  Capital Loss  Hours per week  Country
# 0     4    1        2174.0           0.0            40.0       39
# 1     4    1           0.0           0.0            13.0       39
# 2     4    1           0.0           0.0            40.0       39
# 3     2    1           0.0           0.0            40.0       39
# 4     2    0           0.0           0.0            40.0        5

# %%
explainer = shap.TreeExplainer(model, feature_names = ['Age',
 'Workclass',
 'Education-Num',
 'Marital Status',
 'Occupation',
 'Relationship',
 'Race',
 'Sex',
 'Capital Gain',
 'Capital Loss',
 'Hours per week',
 'Country'])
shap_values = explainer.shap_values(X_train.values)

# %%
shap.summary_plot(shap_values, X_train.values, feature_names = ['Age',
 'Workclass',
 'Education-Num',
 'Marital Status',
 'Occupation',
 'Relationship',
 'Race',
 'Sex',
 'Capital Gain',
 'Capital Loss',
 'Hours per week',
 'Country'], plot_type = 'violin')

# %%
shap.summary_plot(shap_values, train_x)

# %%
X.columns.tolist()
# Out:
# ['Age',
#  'Workclass',
#  'Education-Num',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital Gain',
#  'Capital Loss',
#  'Hours per week',
#  'Country']

# %%
# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.force_plot(
    explainer.expected_value, shap_values[:1000, :], X_display.iloc[:1000, :]
)
# Out:
# <div id='iGYCA83KO9ML54BQ06Z3L'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...
